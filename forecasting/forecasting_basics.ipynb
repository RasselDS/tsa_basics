# %% [markdown]
# The predictability of an event or a quantity depends on several factors including:
#
# - how well we understand the factors that contribute to it;
# - how much data is available;
#     - If there are no data available, or if the data available are not relevant to the forecasts, then qualitative forecasting methods must be used
# - how similar the future is to the past;
# - whether the forecasts can affect the thing we are trying to forecast.

# %% [markdown]
# The basic steps in a forecasting task
#
# -  Problem definition
# - Gathering information
# - Preliminary (exploratory) analysis
# - Choosing and fitting models
# - Using and evaluating a forecasting model

# %% [markdown]
# ![forecasting_basic_definitions.png](attachment:forecasting_basic_definitions.png)

# %% [markdown]
# **Trend**
#
# A trend exists when there is a long-term increase or decrease in the data. It does not have to be linear. Sometimes we will refer to a trend as “changing direction”, when it might go from an increasing trend to a decreasing trend.
#
# **Seasonal**
#
# A seasonal pattern occurs when a time series is affected by seasonal factors such as the time of the year or the day of the week. Seasonality is always of a fixed and known period.
#
# **Cyclic**
#
# A cycle occurs when the data exhibit rises and falls that are not of a fixed frequency. These fluctuations are usually due to economic conditions, and are often related to the “business cycle”. The duration of these fluctuations is usually at least 2 years.

# %% [markdown]
# **White Noise**
#
# Time series that show no autocorrelation are called white noise

# %% [markdown]
# ![white_noise_info.png](attachment:white_noise_info.png)

# %% [markdown]
# # Mathematical transformations

# %% [markdown]
# ![mathematical_transformation.png](attachment:mathematical_transformation.png)

# %% [markdown]
# ![box_cox_transformations.png](attachment:box_cox_transformations.png)

# %% [markdown]
# ![transformations_summary.png](attachment:transformations_summary.png)
