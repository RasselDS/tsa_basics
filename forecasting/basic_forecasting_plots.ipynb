# %% [markdown]
# #### Sample subseries plot

# %% [markdown]
# ![seasonal_subseries_plot_sample.png](attachment:seasonal_subseries_plot_sample.png)

# %% [markdown]
# #### Sample subseries plot in pandas

# %%
subseries_grid = sns.FacetGrid(aus_arrivals, row='Origin', col='Quarter', height=7, aspect=0.7)
subseries_grid.map(sns.lineplot, 'quarter_datetime', 'Arrivals')
subseries_grid.refline(y=aus_arrivals["Arrivals"].median())

# %% [markdown]
# ![subseries_plot_python.png](attachment:subseries_plot_python.png)

# %% [markdown]
# #### Sample seasonal plot

# %% [markdown]
# ![seasonal_plots.png](attachment:seasonal_plots.png)

# %% [markdown]
# #### Sample seasonal plot in pandas

# %%
g = sns.FacetGrid(aus_arrivals, row='Origin', hue='year')
g.map(sns.lineplot, 'Quarter', 'Arrivals').add_legend()

# %% [markdown]
# ![seasonal_plot_python.png](attachment:seasonal_plot_python.png)

# %%
# TODO: Lag plots

# %%
# TODO: ACF plots

# %% [markdown]
# # Trend and Seasonality (ACF)

# %% [markdown]
# ![ACF.png](attachment:ACF.png)

# %% [markdown]
# ![acf_trend_and_seasonality.png](attachment:acf_trend_and_seasonality.png)

# %% [markdown]
# ![sample_acf_plot_interpretation.png](attachment:sample_acf_plot_interpretation.png)

# %% [markdown]
# # White noise

# %% [markdown]
# ![how_to_detect_white_noise.png](attachment:how_to_detect_white_noise.png)
